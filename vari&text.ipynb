# %%
a = 2

b = "3"

print("a =",a,"type =",type (a))
print("b =",b,"type =", type(b))
# Out:
# a = 2 type = <class 'int'>
# b = 3 type = <class 'str'>

# %%
print("a + b =", a+int(b))
# Out:
# a + b = 5

# %%
print("execution started")
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# print("a + b =", a+b)
print("execution ended")
# Out:
# execution started
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 print("execution started")
# ----> 2 print("a + b =", a+b )
#       3 print("execution ended")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print("execution started")
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
# print("a + b =", a+b)
print("a + b =", a+int(b))

print("execution ended")
# Out:
# execution started
# a + b = 5
# execution ended

# %%
print("execution started")
print("converting a into and string + operation , a + b =" str(a) + b)
print("converting b into int  and then  doing + operation , a + b =" a + int(b))
print("execution ended")
